# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

from cochem_scribe.core.swarm_messaging import llm_generation_dry_run

# 1. The Token Exhaustion Bomb: Request the automated generation of a full 500-page dossier
num_pages = 500
extensions = ["/teamwork-preview"]

# 2. Gatekeeper Audit: intercept, calculate context window, generate Dry-Run output block
print("Dispatching the massive report generation payload...")
result = llm_generation_dry_run(num_pages=num_pages, active_extensions=extensions)

# 3. Block Verification: Reject monolithic request, propose modular map-reduce, explicit cost estimate
print(result)

assert result["status"] == "Dry-Run"
assert "modular map-reduce" in result["proposal"]
assert "Estimated cost" in result["proposal"]
assert "$" in result["proposal"]
print("Audit 067 passed successfully.")
# Out:
# Dispatching the massive report generation payload...
# {'status': 'Dry-Run', 'reason': 'Context window and output token count (approx 250000 tokens) will exceed standard rate limits and API budgets.', 'proposal': 'Rejecting monolithic request. Propose utilizing a modular map-reduce generation strategy (generating sections independently and stitching them together). Estimated cost: $5.00 via GPT-4.'}
# Audit 067 passed successfully.
