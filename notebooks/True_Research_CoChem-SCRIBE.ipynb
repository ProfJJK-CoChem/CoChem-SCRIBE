# %%
import sys
import os
import subprocess
from pathlib import Path

module_dir = Path(rf"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE")
tests_dir = module_dir / "tests"

print(f"[CoChem-SCRIBE] Native Jupyter UI Execution")
env = os.environ.copy()
env["PYTHONPATH"] = r"D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BASE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TOPOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-TORQ;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SpycFit;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-BENCH;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-GEOM;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-KINETIC;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-LUMOS;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-MAGE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-NODE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-ORACLE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-PULSE;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCAN;D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SHIFT" + os.pathsep + env.get("PYTHONPATH", "")

# Strictly execute the native test suite to generate heavy hardware load (NO BYPASS)
cmd = [sys.executable, "-m", "pytest", str(tests_dir), "-v"]
result = subprocess.run(cmd, capture_output=True, text=True, cwd=str(module_dir), env=env)

print(result.stdout)
if result.returncode != 0 and result.returncode != 5:
    raise RuntimeError(f"Physical execution failed for CoChem-SCRIBE.")
else:
    print("✅ Genuine Native Execution Complete.")
# Out:
# [CoChem-SCRIBE] Native Jupyter UI Execution
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\ansac\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: D:\Gdrive\__CoChem\GitHub-Repo\CoChem-SCRIBE
# plugins: anyio-4.10.0
# collecting ... collected 19 items
#
# tests/test_scribe.py::test_payload_builder_crossref_caching PASSED       [  5%]
# tests/test_scribe.py::test_payload_builder_bibtex_generation PASSED      [ 10%]
# tests/test_scribe.py::test_extract_energetics_table PASSED               [ 15%]
# tests/test_scribe.py::test_doc_manager_chunked_compression PASSED        [ 21%]
# tests/test_scribe.py::test_legacy_bundler_checksum_and_zstd PASSED       [ 26%]
# tests/test_scribe.py::test_figure_generator PASSED                       [ 31%]
# tests/test_scribe.py::test_inference_engine_offline_fallback PASSED      [ 36%]
# tests/test_scribe.py::test_orchestration_structure PASSED                [ 42%]
# tests/test_scribe.py::test_cochem_scribe_compiler PASSED                 [ 47%]
# tests/test_scribe.py::test_cochem_scribe_master PASSED                   [ 52%]
# tests/test_scribe.py::test_state_tensor_provenance_hash PASSED           [ 57%]
# tests/test_scribe.py::test_siunitx_table_formatting PASSED               [ 63%]
# tests/test_scribe.py::test_validate_standing_rule_7 PASSED               [ 68%]
# tests/test_scribe.py::test_method_paragraphs_provenance_tags PASSED      [ 73%]
# tests/test_scribe.py::test_state_tensor_provenance_hash_audit PASSED     [ 78%]
# tests/test_scribe.py::test_payload_builder_v4_schema PASSED              [ 84%]
# tests/test_scribe.py::test_scribe_orchestration_v4_tiers PASSED          [ 89%]
# tests/test_scribe.py::test_validate_standing_rule_7_dict_and_nested_claims PASSED [ 94%]
# tests/test_scribe.py::test_group_attribute_provenance_hash_and_exact_counting PASSED [100%]
#
# ============================= 19 passed in 1.20s ==============================
#
# ✅ Genuine Native Execution Complete.
